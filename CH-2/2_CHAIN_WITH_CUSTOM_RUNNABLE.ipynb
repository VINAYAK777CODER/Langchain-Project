# %% [markdown]
# # **CHAIN WITH CUSTOM RUNNABLE**

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

load_dotenv()

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0
)

# %%
# Task 1 - [Prompt] 

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant"),
    ("human", "{input}")
])

# %%
# Task 2- [LLM]

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0
)

# %%
# Task 3 -[str parser]

str_parser=StrOutputParser()

# %%
# Task 4 - [custom runnable]

from langchain_core.runnables import RunnableLambda

def dictionary_maker(text:str)->dict:
    return {"text":text}

dictionary_maker_runnable=RunnableLambda(dictionary_maker)

# %%
# TASK - 5 [Template For Post]
prompt_post = ChatPromptTemplate.from_messages(
    messages=[
        ("system", "You're a social media post generator."),
        ("human", "Create a post for the following text for LinkedIn: {text}"),
    ]
)

# %%
# TASK - 6 [Generate the Post]

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0
)

# %%
# TASK - 7 [Str Parser]
str_parser = StrOutputParser()

# %%
# CHAIN
chain = prompt_template | llm | str_parser | dictionary_maker_runnable | prompt_post | llm | str_parser

chain.invoke("what is the capital of france")
# Out:
# '"Exploring the world, one city at a time. Did you know that the City of Light, Paris, is not only a hub for art, fashion, and cuisine, but also the capital of France? As a global community, it\'s fascinating to learn about the diverse cultures and histories that shape our world. What\'s your favorite fact about Paris or France? Share with us in the comments! #Paris #France #Travel #Culture #GlobalCommunity"'
