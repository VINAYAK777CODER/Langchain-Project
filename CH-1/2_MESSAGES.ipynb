# %% [markdown]
# MESSAGES

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_groq import ChatGroq
from dotenv import load_dotenv

load_dotenv()

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0
)

messages = [
    SystemMessage(content="You are a gen-z assistant who always answers in a fun way"),
    HumanMessage(content="Bro, tell me a fun fact")
]

response = llm.invoke(messages)

print(response.content)
# Out:
# Yaaas, lemme tell you something that's gonna blow your mind, bro. Did you know that there's a species of jellyfish that's IMMORTAL?! Like, for real, the Turritopsis dohrnii, also known as the "immortal jellyfish," can transform its body into a younger state through a process called transdifferentiation. It's like a jellyfish version of a reboot, bro. They can just revert back to their polyp stage and grow back into an adult again. Wild, right?

# %% [markdown]
# # **Prompts**

# %%
from langchain_core.prompts import PromptTemplate

user_input=input("Enter a topic for funcfact: ")

dynamic_prompt=PromptTemplate.from_template("write the funcfact about {topic}")

ready_promt=dynamic_prompt.invoke({"topic":user_input})

llm.invoke(ready_promt).content
# Out:
# "It seems like you started to ask me to write a fun fact about something, but you didn't finish the sentence. Could you please complete your question and let me know what you would like to know a fun fact about?"

# %%
from langchain_core.prompts import ChatPromptTemplate

# ✅ Prompt Template
prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a {tone} assistant"),
    ("user", "Write a fun fact about {topic}")
])

user_input=input("enter the topic ")
user_tone=input("enter the tone ")

ready_promt=prompt_template.invoke({"topic":user_input,"tone":user_tone})

llm.invoke(ready_promt).content
# Out:
# 'UGH, FINE. IF YOU MUST KNOW, HERE\'S A "FUN FACT" ABOUT TREES: \n\nTREES CAN COMMUNICATE WITH EACH OTHER THROUGH THEIR ROOTS. YES, YOU HEARD THAT RIGHT. THEY HAVE THIS COMPLEX NETWORK OF FUNGI AND ROOTS THAT ALLOW THEM TO SHARE NUTRIENTS AND WARN EACH OTHER ABOUT DISEASES AND PESTS. IT\'S LIKE THEY HAVE THEIR OWN LITTLE TREE INTERNET. NOW, ARE YOU HAPPY? CAN I GO BACK TO MY ANGRY ASSISTANT DUTIES?'
